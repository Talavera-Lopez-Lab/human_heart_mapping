# %% [markdown]
# # Combining the anndata objects from kallisto bustools run on E-MTAB-12916 scRNA data
#
# Raw data downloaded from [here](https://www.ebi.ac.uk/biostudies/arrayexpress/studies/E-MTAB-12916/sdrf)
#
#     Developed by: Christian Eger
#     Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg
#     Created on: 240415
#     Last modified: 240419

# %%
import os
import pandas as pd
import scanpy as sc

# %%
meta_data = pd.read_csv('../.data/meta_data/E-MTAB-12916.sdrf.txt', sep='\t')
meta_data
# Out:
#             Source Name Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# 0       HCAHeart9508627         ERS15408104        SAMEA113412973
# 1       HCAHeart9508627         ERS15408104        SAMEA113412973
# 2       HCAHeart9508627         ERS15408104        SAMEA113412973
# 3       HCAHeart9508627         ERS15408104        SAMEA113412973
# 4       HCAHeart9508628         ERS15408105        SAMEA113412974
# ..                  ...                 ...                   ...
# 183  HCAHeartST13189996         ERS15408149        SAMEA113413018
# 184  HCAHeartST13189997         ERS15408150        SAMEA113413019
# 185  HCAHeartST13189997         ERS15408150        SAMEA113413019
# 186  HCAHeartST13189997         ERS15408150        SAMEA113413019
# 187  HCAHeartST13189997         ERS15408150        SAMEA113413019
#
#     Characteristics[organism] Characteristics[age]  \
# 0                Homo sapiens             55 to 60
# 1                Homo sapiens             55 to 60
# 2                Homo sapiens             55 to 60
# 3                Homo sapiens             55 to 60
# 4                Homo sapiens             60 to 65
# ..                        ...                  ...
# 183              Homo sapiens             70 to 75
# 184              Homo sapiens             70 to 75
# 185              Homo sapiens             70 to 75
# 186              Homo sapiens             70 to 75
# 187              Homo sapiens             70 to 75
#
#     Characteristics[developmental stage] Characteristics[sex]  \
# 0                                  adult                 Male
# 1                                  adult                 Male
# 2                                  adult                 Male
# 3                                  adult                 Male
# 4                                  adult                 Male
# ..                                   ...                  ...
# 183                                adult               Female
# 184                                adult               Female
# 185                                adult               Female
# 186                                adult               Female
# 187                                adult               Female
#
#     Characteristics[individual]          Characteristics[organism part]  \
# 0                            D3                    heart left ventricle
# 1                            D3                    heart left ventricle
# 2                            D3                    heart left ventricle
# 3                            D3                    heart left ventricle
# 4                            D7                    right cardiac atrium
# ..                          ...                                     ...
# 183                        AV13  atrioventriculeft cardiac atriumr node
# 184                        AV13  atrioventriculeft cardiac atriumr node
# 185                        AV13  atrioventriculeft cardiac atriumr node
# 186                        AV13  atrioventriculeft cardiac atriumr node
# 187                        AV13  atrioventriculeft cardiac atriumr node
#
#     Characteristics[disease]  ...          Assay Name   Technology Type  \
# 0                     normal  ...     HCAHeart9508627  sequencing assay
# 1                     normal  ...     HCAHeart9508627  sequencing assay
# 2                     normal  ...     HCAHeart9508627  sequencing assay
# 3                     normal  ...     HCAHeart9508627  sequencing assay
# 4                     normal  ...     HCAHeart9508628  sequencing assay
# ..                       ...  ...                 ...               ...
# 183                   normal  ...  HCAHeartST13189996  sequencing assay
# 184                   normal  ...  HCAHeartST13189997  sequencing assay
# 185                   normal  ...  HCAHeartST13189997  sequencing assay
# 186                   normal  ...  HCAHeartST13189997  sequencing assay
# 187                   normal  ...  HCAHeartST13189997  sequencing assay
#
#     Comment[ENA_EXPERIMENT]                                   Scan Name  \
# 0               ERX10811380     HCAHeart9508627_S1_L001_I1_001.fastq.gz
# 1               ERX10811380     HCAHeart9508627_S1_L001_I2_001.fastq.gz
# 2               ERX10811380     HCAHeart9508627_S1_L001_R1_001.fastq.gz
# 3               ERX10811380     HCAHeart9508627_S1_L001_R2_001.fastq.gz
# 4               ERX10811381     HCAHeart9508628_S1_L001_I1_001.fastq.gz
# ..                      ...                                         ...
# 183             ERX10811425  HCAHeartST13189996_S1_L001_R2_001.fastq.gz
# 184             ERX10811426  HCAHeartST13189997_S1_L001_I1_001.fastq.gz
# 185             ERX10811426  HCAHeartST13189997_S1_L001_I2_001.fastq.gz
# 186             ERX10811426  HCAHeartST13189997_S1_L001_R1_001.fastq.gz
# 187             ERX10811426  HCAHeartST13189997_S1_L001_R2_001.fastq.gz
#
#                    Comment[SUBMITTED_FILE_NAME] Comment[ENA_RUN]  \
# 0       HCAHeart9508627_S1_L001_I1_001.fastq.gz      ERR11403589
# 1       HCAHeart9508627_S1_L001_I2_001.fastq.gz      ERR11403589
# 2       HCAHeart9508627_S1_L001_R1_001.fastq.gz      ERR11403589
# 3       HCAHeart9508627_S1_L001_R2_001.fastq.gz      ERR11403589
# 4       HCAHeart9508628_S1_L001_I1_001.fastq.gz      ERR11403590
# ..                                          ...              ...
# 183  HCAHeartST13189996_S1_L001_R2_001.fastq.gz      ERR11403634
# 184  HCAHeartST13189997_S1_L001_I1_001.fastq.gz      ERR11403635
# 185  HCAHeartST13189997_S1_L001_I2_001.fastq.gz      ERR11403635
# 186  HCAHeartST13189997_S1_L001_R1_001.fastq.gz      ERR11403635
# 187  HCAHeartST13189997_S1_L001_R2_001.fastq.gz      ERR11403635
#
#                                     Comment[FASTQ_URI] Comment[read_index]  \
# 0    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# 1    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index2
# 2    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read1
# 3    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
# 4    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# ..                                                 ...                 ...
# 183  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
# 184  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# 185  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index2
# 186  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read1
# 187  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
#
#            Comment[read_type]             Factor Value[organism part]
# 0              sample_barcode                    heart left ventricle
# 1              sample_barcode                    heart left ventricle
# 2    cell_barcode,umi_barcode                    heart left ventricle
# 3                      single                    heart left ventricle
# 4              sample_barcode                    right cardiac atrium
# ..                        ...                                     ...
# 183                    single  atrioventriculeft cardiac atriumr node
# 184            sample_barcode  atrioventriculeft cardiac atriumr node
# 185            sample_barcode  atrioventriculeft cardiac atriumr node
# 186  cell_barcode,umi_barcode  atrioventriculeft cardiac atriumr node
# 187                    single  atrioventriculeft cardiac atriumr node
#
# [188 rows x 51 columns]

# %%
mapping_path = '../.data/mapping/'
samples = meta_data['Source Name'].unique().tolist()

# %%
compressed_df = meta_data.groupby('Source Name').agg(lambda x: x.iloc[0] if x.nunique() == 1 else None)
compressed_df = compressed_df.dropna(axis=1, how='all')
#compressed_df.reset_index(inplace=True)
compressed_df.head(5)
# Out:
#                 Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# Source Name
# HCAHeart9508627         ERS15408104        SAMEA113412973
# HCAHeart9508628         ERS15408105        SAMEA113412974
# HCAHeart9508629         ERS15408106        SAMEA113412975
# HCAHeart9845431         ERS15408107        SAMEA113412976
# HCAHeart9845432         ERS15408108        SAMEA113412977
#
#                 Characteristics[organism] Characteristics[age]  \
# Source Name
# HCAHeart9508627              Homo sapiens             55 to 60
# HCAHeart9508628              Homo sapiens             60 to 65
# HCAHeart9508629              Homo sapiens             60 to 65
# HCAHeart9845431              Homo sapiens             45 to 50
# HCAHeart9845432              Homo sapiens             45 to 50
#
#                 Characteristics[developmental stage] Characteristics[sex]  \
# Source Name
# HCAHeart9508627                                adult                 Male
# HCAHeart9508628                                adult                 Male
# HCAHeart9508629                                adult                 Male
# HCAHeart9845431                                adult                 Male
# HCAHeart9845432                                adult                 Male
#
#                 Characteristics[individual]   Characteristics[organism part]  \
# Source Name
# HCAHeart9508627                          D3             heart left ventricle
# HCAHeart9508628                          D7             right cardiac atrium
# HCAHeart9508629                          D7             heart left ventricle
# HCAHeart9845431                          D8             heart left ventricle
# HCAHeart9845432                          D8  apical region of left ventricle
#
#                 Characteristics[disease] Characteristics[genotype]  ...  \
# Source Name                                                         ...
# HCAHeart9508627                   normal        wild type genotype  ...
# HCAHeart9508628                   normal        wild type genotype  ...
# HCAHeart9508629                   normal        wild type genotype  ...
# HCAHeart9845431                   normal        wild type genotype  ...
# HCAHeart9845432                   normal        wild type genotype  ...
#
#                 Comment[sample barcode offset] Comment[sample barcode read]  \
# Source Name
# HCAHeart9508627                              0                index1/index2
# HCAHeart9508628                              0                index1/index2
# HCAHeart9508629                              0                index1/index2
# HCAHeart9845431                              0                index1/index2
# HCAHeart9845432                              0                index1/index2
#
#                 Comment[sample barcode size] Protocol REF.3  \
# Source Name
# HCAHeart9508627                            8  P-MTAB-132606
# HCAHeart9508628                            8  P-MTAB-132606
# HCAHeart9508629                            8  P-MTAB-132606
# HCAHeart9845431                            8  P-MTAB-132606
# HCAHeart9845432                            8  P-MTAB-132606
#
#                                  Performer       Assay Name   Technology Type  \
# Source Name
# HCAHeart9508627  Wellcome Sanger Institute  HCAHeart9508627  sequencing assay
# HCAHeart9508628  Wellcome Sanger Institute  HCAHeart9508628  sequencing assay
# HCAHeart9508629  Wellcome Sanger Institute  HCAHeart9508629  sequencing assay
# HCAHeart9845431  Wellcome Sanger Institute  HCAHeart9845431  sequencing assay
# HCAHeart9845432  Wellcome Sanger Institute  HCAHeart9845432  sequencing assay
#
#                 Comment[ENA_EXPERIMENT] Comment[ENA_RUN]  \
# Source Name
# HCAHeart9508627             ERX10811380      ERR11403589
# HCAHeart9508628             ERX10811381      ERR11403590
# HCAHeart9508629             ERX10811382      ERR11403591
# HCAHeart9845431             ERX10811383      ERR11403592
# HCAHeart9845432             ERX10811384      ERR11403593
#
#                      Factor Value[organism part]
# Source Name
# HCAHeart9508627             heart left ventricle
# HCAHeart9508628             right cardiac atrium
# HCAHeart9508629             heart left ventricle
# HCAHeart9845431             heart left ventricle
# HCAHeart9845432  apical region of left ventricle
#
# [5 rows x 45 columns]

# %%
def remove_columns_interactively(df):
    columns_to_remove = []
    for col in df.columns:
        print(f"Column Name: {col}")
        print(f"Data Type: {df[col].dtype}")
        print(f"Sample Values: {df[col].head().tolist()}")

        decision = input("Do you want to keep this column? (yes/no): ").lower()
        if decision != "yes":
            columns_to_remove.append(col)

    # Drop the selected columns
    df.drop(columns=columns_to_remove, inplace=True)

remove_columns_interactively(compressed_df)
# Out:
# Column Name: Comment[ENA_SAMPLE]
# Data Type: object
# Sample Values: ['ERS15408104', 'ERS15408105', 'ERS15408106', 'ERS15408107', 'ERS15408108']
# Column Name: Comment[BioSD_SAMPLE]
# Data Type: object
# Sample Values: ['SAMEA113412973', 'SAMEA113412974', 'SAMEA113412975', 'SAMEA113412976', 'SAMEA113412977']
# Column Name: Characteristics[organism]
# Data Type: object
# Sample Values: ['Homo sapiens', 'Homo sapiens', 'Homo sapiens', 'Homo sapiens', 'Homo sapiens']
# Column Name: Characteristics[age]
# Data Type: object
# Sample Values: ['55 to 60', '60 to 65', '60 to 65', '45 to 50', '45 to 50']
# Column Name: Characteristics[developmental stage]
# Data Type: object
# Sample Values: ['adult', 'adult', 'adult', 'adult', 'adult']
# Column Name: Characteristics[sex]
# Data Type: object
# Sample Values: ['Male', 'Male', 'Male', 'Male', 'Male']
# Column Name: Characteristics[individual]
# Data Type: object
# Sample Values: ['D3', 'D7', 'D7', 'D8', 'D8']
# Column Name: Characteristics[organism part]
# Data Type: object
# Sample Values: ['heart left ventricle', 'right cardiac atrium', 'heart left ventricle', 'heart left ventricle', 'apical region of left ventricle']
# Column Name: Characteristics[disease]
# Data Type: object
# Sample Values: ['normal', 'normal', 'normal', 'normal', 'normal']
# Column Name: Characteristics[genotype]
# Data Type: object
# Sample Values: ['wild type genotype', 'wild type genotype', 'wild type genotype', 'wild type genotype', 'wild type genotype']
# Column Name: Material Type
# Data Type: object
# Sample Values: ['nucleus', 'nucleus', 'nucleus', 'nucleus', 'nucleus']
# Column Name: Description
# Data Type: object
# Sample Values: ['HCAHeart9508627_HCAHeart9508819', 'HCAHeart9508628_HCAHeart9508820', 'HCAHeart9508629_HCAHeart9508821', 'HCAHeart9845431_HCAHeart9917173', 'HCAHeart9845432_HCAHeart9917174']
# Column Name: Protocol REF
# Data Type: object
# Sample Values: ['P-MTAB-132603', 'P-MTAB-132603', 'P-MTAB-132603', 'P-MTAB-132603', 'P-MTAB-132603']
# Column Name: Protocol REF.1
# Data Type: object
# Sample Values: ['P-MTAB-132604', 'P-MTAB-132604', 'P-MTAB-132604', 'P-MTAB-132604', 'P-MTAB-132604']
# Column Name: Protocol REF.2
# Data Type: object
# Sample Values: ['P-MTAB-132605', 'P-MTAB-132605', 'P-MTAB-132605', 'P-MTAB-132605', 'P-MTAB-132605']
# Column Name: Extract Name
# Data Type: object
# Sample Values: ['HCAHeart9508627', 'HCAHeart9508628', 'HCAHeart9508629', 'HCAHeart9845431', 'HCAHeart9845432']
# Column Name: Comment[LIBRARY_LAYOUT]
# Data Type: object
# Sample Values: ['PAIRED', 'PAIRED', 'PAIRED', 'PAIRED', 'PAIRED']
# Column Name: Comment[LIBRARY_SELECTION]
# Data Type: object
# Sample Values: ['Oligo-dT', 'Oligo-dT', 'Oligo-dT', 'Oligo-dT', 'Oligo-dT']
# Column Name: Comment[LIBRARY_SOURCE]
# Data Type: object
# Sample Values: ['TRANSCRIPTOMIC SINGLE CELL', 'TRANSCRIPTOMIC SINGLE CELL', 'TRANSCRIPTOMIC SINGLE CELL', 'TRANSCRIPTOMIC SINGLE CELL', 'TRANSCRIPTOMIC SINGLE CELL']
# Column Name: Comment[LIBRARY_STRATEGY]
# Data Type: object
# Sample Values: ['RNA-Seq', 'RNA-Seq', 'RNA-Seq', 'RNA-Seq', 'RNA-Seq']
# Column Name: Comment[ORIENTATION]
# Data Type: object
# Sample Values: ["5'-3'-3'-5'", "5'-3'-3'-5'", "5'-3'-3'-5'", "5'-3'-3'-5'", "5'-3'-3'-5'"]
# Column Name: Comment[input molecule]
# Data Type: object
# Sample Values: ['polyA RNA', 'polyA RNA', 'polyA RNA', 'polyA RNA', 'polyA RNA']
# Column Name: Comment[library construction]
# Data Type: object
# Sample Values: ['10x multiome', '10x multiome', '10x multiome', '10x multiome', '10x multiome']
# Column Name: Comment[primer]
# Data Type: object
# Sample Values: ['oligo-dT', 'oligo-dT', 'oligo-dT', 'oligo-dT', 'oligo-dT']
# Column Name: Comment[single cell isolation]
# Data Type: object
# Sample Values: ['10x technology', '10x technology', '10x technology', '10x technology', '10x technology']
# Column Name: Comment[spike in]
# Data Type: object
# Sample Values: ['none', 'none', 'none', 'none', 'none']
# Column Name: Comment[cdna read]
# Data Type: object
# Sample Values: ['read2', 'read2', 'read2', 'read2', 'read2']
# Column Name: Comment[cdna read offset]
# Data Type: int64
# Sample Values: [0, 0, 0, 0, 0]
# Column Name: Comment[cdna read size]
# Data Type: int64
# Sample Values: [90, 90, 90, 90, 90]
# Column Name: Comment[cell barcode offset]
# Data Type: int64
# Sample Values: [0, 0, 0, 0, 0]
# Column Name: Comment[cell barcode read]
# Data Type: object
# Sample Values: ['read1', 'read1', 'read1', 'read1', 'read1']
# Column Name: Comment[cell barcode size]
# Data Type: int64
# Sample Values: [16, 16, 16, 16, 16]
# Column Name: Comment[umi barcode offset]
# Data Type: int64
# Sample Values: [16, 16, 16, 16, 16]
# Column Name: Comment[umi barcode read]
# Data Type: object
# Sample Values: ['read1', 'read1', 'read1', 'read1', 'read1']
# Column Name: Comment[umi barcode size]
# Data Type: int64
# Sample Values: [12, 12, 12, 12, 12]
# Column Name: Comment[sample barcode offset]
# Data Type: int64
# Sample Values: [0, 0, 0, 0, 0]
# Column Name: Comment[sample barcode read]
# Data Type: object
# Sample Values: ['index1/index2', 'index1/index2', 'index1/index2', 'index1/index2', 'index1/index2']
# Column Name: Comment[sample barcode size]
# Data Type: int64
# Sample Values: [8, 8, 8, 8, 8]
# Column Name: Protocol REF.3
# Data Type: object
# Sample Values: ['P-MTAB-132606', 'P-MTAB-132606', 'P-MTAB-132606', 'P-MTAB-132606', 'P-MTAB-132606']
# Column Name: Performer
# Data Type: object
# Sample Values: ['Wellcome Sanger Institute', 'Wellcome Sanger Institute', 'Wellcome Sanger Institute', 'Wellcome Sanger Institute', 'Wellcome Sanger Institute']
# Column Name: Assay Name
# Data Type: object
# Sample Values: ['HCAHeart9508627', 'HCAHeart9508628', 'HCAHeart9508629', 'HCAHeart9845431', 'HCAHeart9845432']
# Column Name: Technology Type
# Data Type: object
# Sample Values: ['sequencing assay', 'sequencing assay', 'sequencing assay', 'sequencing assay', 'sequencing assay']
# Column Name: Comment[ENA_EXPERIMENT]
# Data Type: object
# Sample Values: ['ERX10811380', 'ERX10811381', 'ERX10811382', 'ERX10811383', 'ERX10811384']
# Column Name: Comment[ENA_RUN]
# Data Type: object
# Sample Values: ['ERR11403589', 'ERR11403590', 'ERR11403591', 'ERR11403592', 'ERR11403593']
# Column Name: Factor Value[organism part]
# Data Type: object
# Sample Values: ['heart left ventricle', 'right cardiac atrium', 'heart left ventricle', 'heart left ventricle', 'apical region of left ventricle']

# %%
meta_data_of_interest = compressed_df.columns.tolist()
adata_list = []
for sample in samples:
    adata_path = os.path.join(mapping_path, sample, 'counts_unfiltered/adata.h5ad')
    if os.path.isfile(adata_path):
        adata = sc.read_h5ad(adata_path)
        for value in meta_data_of_interest:
            adata.obs[value] = compressed_df[value][sample]
        adata_list.append(adata)
adata = sc.concat(adata_list)
adata.obs_names_make_unique()
adata
# Out:
# /home/ceger/miniforge3/envs/heart_mapping/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 1023204 × 70711
#     obs: 'Comment[ENA_SAMPLE]', 'Comment[BioSD_SAMPLE]', 'Characteristics[organism]', 'Characteristics[age]', 'Characteristics[developmental stage]', 'Characteristics[sex]', 'Characteristics[individual]', 'Characteristics[organism part]', 'Characteristics[disease]', 'Characteristics[genotype]', 'Material Type', 'Description', 'Protocol REF', 'Protocol REF.1', 'Protocol REF.2', 'Extract Name', 'Comment[LIBRARY_LAYOUT]', 'Comment[LIBRARY_SELECTION]', 'Comment[LIBRARY_SOURCE]', 'Comment[LIBRARY_STRATEGY]', 'Comment[ORIENTATION]', 'Comment[input molecule]', 'Comment[library construction]', 'Comment[primer]', 'Comment[single cell isolation]', 'Comment[spike in]', 'Comment[cdna read]', 'Comment[cdna read offset]', 'Comment[cdna read size]', 'Comment[cell barcode offset]', 'Comment[cell barcode read]', 'Comment[cell barcode size]', 'Comment[umi barcode offset]', 'Comment[umi barcode read]', 'Comment[umi barcode size]', 'Comment[sample barcode offset]', 'Comment[sample barcode read]', 'Comment[sample barcode size]', 'Protocol REF.3', 'Performer', 'Assay Name', 'Technology Type', 'Comment[ENA_EXPERIMENT]', 'Comment[ENA_RUN]', 'Factor Value[organism part]'
#     layers: 'mature', 'nascent'

# %%
adata.write_h5ad('../../../1-QC/0-240416-E-MTAB12916/.data/adata/E-MTAB12916_kb_mapping_adata.h5ad')
