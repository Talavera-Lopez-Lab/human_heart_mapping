# %% [markdown]
# # Notebook for mapping scRNAseq Data
#
# Raw data downloaded from [here](https://www.ebi.ac.uk/biostudies/arrayexpress/studies/E-MTAB-12916/sdrf)
#
#     Developed by: Christian Eger
#     Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg
#     Created on: 240411
#     Last modified: 240415

# %% [markdown]
# ## Import modules

# %%
import os
import pandas as pd
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating input file for download and processing script
#
# Downloaded from [**here**](https://www.ebi.ac.uk/biostudies/arrayexpress/studies/E-MTAB-12916?query=E-MTAB-12916)

# %%
data_path = '../../raw_data/'
meta_data_file = 'E-MTAB-12916.sdrf.txt'

# %%
meta_data = pd.read_csv(os.path.join(data_path, meta_data_file), sep='\t')
meta_data
# Out:
#             Source Name Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# 0       HCAHeart9508627         ERS15408104        SAMEA113412973
# 1       HCAHeart9508627         ERS15408104        SAMEA113412973
# 2       HCAHeart9508627         ERS15408104        SAMEA113412973
# 3       HCAHeart9508627         ERS15408104        SAMEA113412973
# 4       HCAHeart9508628         ERS15408105        SAMEA113412974
# ..                  ...                 ...                   ...
# 183  HCAHeartST13189996         ERS15408149        SAMEA113413018
# 184  HCAHeartST13189997         ERS15408150        SAMEA113413019
# 185  HCAHeartST13189997         ERS15408150        SAMEA113413019
# 186  HCAHeartST13189997         ERS15408150        SAMEA113413019
# 187  HCAHeartST13189997         ERS15408150        SAMEA113413019
#
#     Characteristics[organism] Characteristics[age]  \
# 0                Homo sapiens             55 to 60
# 1                Homo sapiens             55 to 60
# 2                Homo sapiens             55 to 60
# 3                Homo sapiens             55 to 60
# 4                Homo sapiens             60 to 65
# ..                        ...                  ...
# 183              Homo sapiens             70 to 75
# 184              Homo sapiens             70 to 75
# 185              Homo sapiens             70 to 75
# 186              Homo sapiens             70 to 75
# 187              Homo sapiens             70 to 75
#
#     Characteristics[developmental stage] Characteristics[sex]  \
# 0                                  adult                 Male
# 1                                  adult                 Male
# 2                                  adult                 Male
# 3                                  adult                 Male
# 4                                  adult                 Male
# ..                                   ...                  ...
# 183                                adult               Female
# 184                                adult               Female
# 185                                adult               Female
# 186                                adult               Female
# 187                                adult               Female
#
#     Characteristics[individual]          Characteristics[organism part]  \
# 0                            D3                    heart left ventricle
# 1                            D3                    heart left ventricle
# 2                            D3                    heart left ventricle
# 3                            D3                    heart left ventricle
# 4                            D7                    right cardiac atrium
# ..                          ...                                     ...
# 183                        AV13  atrioventriculeft cardiac atriumr node
# 184                        AV13  atrioventriculeft cardiac atriumr node
# 185                        AV13  atrioventriculeft cardiac atriumr node
# 186                        AV13  atrioventriculeft cardiac atriumr node
# 187                        AV13  atrioventriculeft cardiac atriumr node
#
#     Characteristics[disease]  ...          Assay Name   Technology Type  \
# 0                     normal  ...     HCAHeart9508627  sequencing assay
# 1                     normal  ...     HCAHeart9508627  sequencing assay
# 2                     normal  ...     HCAHeart9508627  sequencing assay
# 3                     normal  ...     HCAHeart9508627  sequencing assay
# 4                     normal  ...     HCAHeart9508628  sequencing assay
# ..                       ...  ...                 ...               ...
# 183                   normal  ...  HCAHeartST13189996  sequencing assay
# 184                   normal  ...  HCAHeartST13189997  sequencing assay
# 185                   normal  ...  HCAHeartST13189997  sequencing assay
# 186                   normal  ...  HCAHeartST13189997  sequencing assay
# 187                   normal  ...  HCAHeartST13189997  sequencing assay
#
#     Comment[ENA_EXPERIMENT]                                   Scan Name  \
# 0               ERX10811380     HCAHeart9508627_S1_L001_I1_001.fastq.gz
# 1               ERX10811380     HCAHeart9508627_S1_L001_I2_001.fastq.gz
# 2               ERX10811380     HCAHeart9508627_S1_L001_R1_001.fastq.gz
# 3               ERX10811380     HCAHeart9508627_S1_L001_R2_001.fastq.gz
# 4               ERX10811381     HCAHeart9508628_S1_L001_I1_001.fastq.gz
# ..                      ...                                         ...
# 183             ERX10811425  HCAHeartST13189996_S1_L001_R2_001.fastq.gz
# 184             ERX10811426  HCAHeartST13189997_S1_L001_I1_001.fastq.gz
# 185             ERX10811426  HCAHeartST13189997_S1_L001_I2_001.fastq.gz
# 186             ERX10811426  HCAHeartST13189997_S1_L001_R1_001.fastq.gz
# 187             ERX10811426  HCAHeartST13189997_S1_L001_R2_001.fastq.gz
#
#                    Comment[SUBMITTED_FILE_NAME] Comment[ENA_RUN]  \
# 0       HCAHeart9508627_S1_L001_I1_001.fastq.gz      ERR11403589
# 1       HCAHeart9508627_S1_L001_I2_001.fastq.gz      ERR11403589
# 2       HCAHeart9508627_S1_L001_R1_001.fastq.gz      ERR11403589
# 3       HCAHeart9508627_S1_L001_R2_001.fastq.gz      ERR11403589
# 4       HCAHeart9508628_S1_L001_I1_001.fastq.gz      ERR11403590
# ..                                          ...              ...
# 183  HCAHeartST13189996_S1_L001_R2_001.fastq.gz      ERR11403634
# 184  HCAHeartST13189997_S1_L001_I1_001.fastq.gz      ERR11403635
# 185  HCAHeartST13189997_S1_L001_I2_001.fastq.gz      ERR11403635
# 186  HCAHeartST13189997_S1_L001_R1_001.fastq.gz      ERR11403635
# 187  HCAHeartST13189997_S1_L001_R2_001.fastq.gz      ERR11403635
#
#                                     Comment[FASTQ_URI] Comment[read_index]  \
# 0    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# 1    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index2
# 2    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read1
# 3    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
# 4    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# ..                                                 ...                 ...
# 183  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
# 184  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# 185  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index2
# 186  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read1
# 187  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
#
#            Comment[read_type]             Factor Value[organism part]
# 0              sample_barcode                    heart left ventricle
# 1              sample_barcode                    heart left ventricle
# 2    cell_barcode,umi_barcode                    heart left ventricle
# 3                      single                    heart left ventricle
# 4              sample_barcode                    right cardiac atrium
# ..                        ...                                     ...
# 183                    single  atrioventriculeft cardiac atriumr node
# 184            sample_barcode  atrioventriculeft cardiac atriumr node
# 185            sample_barcode  atrioventriculeft cardiac atriumr node
# 186  cell_barcode,umi_barcode  atrioventriculeft cardiac atriumr node
# 187                    single  atrioventriculeft cardiac atriumr node
#
# [188 rows x 51 columns]

# %%
meta_data = meta_data[['Source Name', 'Comment[FASTQ_URI]', 'Comment[SUBMITTED_FILE_NAME]']]
meta_data.to_csv('../../raw_data/downloads_table.csv', header=None)
meta_data
# Out:
#             Source Name                                 Comment[FASTQ_URI]  \
# 0       HCAHeart9508627  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 1       HCAHeart9508627  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 2       HCAHeart9508627  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 3       HCAHeart9508627  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 4       HCAHeart9508628  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# ..                  ...                                                ...
# 183  HCAHeartST13189996  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 184  HCAHeartST13189997  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 185  HCAHeartST13189997  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 186  HCAHeartST13189997  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 187  HCAHeartST13189997  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
#
#                    Comment[SUBMITTED_FILE_NAME]
# 0       HCAHeart9508627_S1_L001_I1_001.fastq.gz
# 1       HCAHeart9508627_S1_L001_I2_001.fastq.gz
# 2       HCAHeart9508627_S1_L001_R1_001.fastq.gz
# 3       HCAHeart9508627_S1_L001_R2_001.fastq.gz
# 4       HCAHeart9508628_S1_L001_I1_001.fastq.gz
# ..                                          ...
# 183  HCAHeartST13189996_S1_L001_R2_001.fastq.gz
# 184  HCAHeartST13189997_S1_L001_I1_001.fastq.gz
# 185  HCAHeartST13189997_S1_L001_I2_001.fastq.gz
# 186  HCAHeartST13189997_S1_L001_R1_001.fastq.gz
# 187  HCAHeartST13189997_S1_L001_R2_001.fastq.gz
#
# [188 rows x 3 columns]

# %% [markdown]
# ## Index file creation
#
# **Comprehensive gene annotation ALL:**
# - It contains the comprehensive gene annotation on the reference chromosomes, scaffolds, assembly patches and alternate loci (haplotypes)
#
# **Long non-coding RNA gene annotation CHR:**
# - It contains the comprehensive gene annotation of lncRNA genes on the reference chromosomes
#
# **Genome sequence (GRCh38.p14) ALL:**
# - Nucleotide sequence of the GRCh38.p14 genome assembly version on all regions, including reference chromosomes, scaffolds, assembly patches and haplotypes
# - The sequence region names are the same as in the GTF/GFF3 files
#
# downloaded from [**here**](https://www.gencodegenes.org/human/)

# %%
# %%bash
# index_input="../../reference_data/"
# ls $index_input
# Out:
# gencode.v45.chr_patch_hapl_scaff.annotation.gtf.gz
# gencode.v45.long_noncoding_RNAs.gtf.gz
# gencode.v45.tRNAs.gtf.gz
# GRCh38.p14.genome.fa.gz

# %%
# %%bash
# index_input="../../reference_data/"
# index_output="../../kb_index/"
#
# if [ ! -d "$index_output" ]; then
#     mkdir -p "$index_output"
# fi
#
# kb ref -i "$index_output/transcriptome.idx" \
#         -g "$index_output/transcripts_to_genes.txt" \
#         -f1 "$index_output/cdna.fa" \
#         "$index_input/GRCh38.p14.genome.fa.gz" \
#         "$index_input/gencode.v45.chr_patch_hapl_scaff.annotation.gtf.gz" \
#         "$index_input/gencode.v45.long_noncoding_RNAs.gtf.gz" \
# Out:
# [2024-04-11 14:54:36,459]    INFO [ref] Preparing ../../reference_data//GRCh38.p14.genome.fa.gz, ../../reference_data//gencode.v45.chr_patch_hapl_scaff.annotation.gtf.gz
# [2024-04-11 14:55:24,588]    INFO [ref] Splitting genome ../../reference_data//GRCh38.p14.genome.fa.gz into cDNA at /mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/tmp/tmpjlu9txpo
# [2024-04-11 14:56:39,057]    INFO [ref] Concatenating 1 cDNAs to ../../kb_index//cdna.fa
# [2024-04-11 14:56:39,774]    INFO [ref] Creating transcript-to-gene mapping at ../../kb_index//transcripts_to_genes.txt
# [2024-04-11 14:56:41,234]    INFO [ref] Indexing ../../kb_index//cdna.fa to ../../kb_index//transcriptome.idx

# %% [markdown]
# ## *optional: Preparations before continuing an aborted mapping process

# %%
# %%bash
#
# directory="../../mapping"
# #!/bin/bash
#
#
# # Find folders that don't contain the specific file
# while IFS= read -r folder; do
#     if [ ! -f "$folder/10x_version3_whitelist.txt" ]; then
#         echo "$folder"
#         break  # Exit the loop after finding the first folder without the file
#     fi
# done < <(find "$directory" -mindepth 1 -maxdepth 1 -type d)
# Out:
# ../../mapping/HCAHeartST13180619

# %% [markdown]
# make sure that is the correct folder and then delete it

# %%
# %%bash
#
# rm -rf ../../mapping/HCAHeartST13180619

# %%
# %%bash
# # Directory to search within
# directory="../../mapping"
#
# # Find folders that contain the specific file
# # Find folders that contain the specific file
# folders=$(find "$directory" -mindepth 1 -maxdepth 1 -type d -exec test -e "{}/10x_version3_whitelist.txt" \; -printf "'%f',\n")
#
# # Remove the trailing comma
# folders="${folders%,}"
#
# # Print the folders in comma-separated format within brackets
# echo "[${folders}]"
# Out:
# ['HCAHeartST13146201',
# 'HCAHeartST10773170',
# 'HCAHeart9845433',
# 'HCAHeartST10773171',
# 'HCAHeartST11064577',
# 'HCAHeartST10773169',
# 'HCAHeartST11350194',
# 'HCAHeartST13180616',
# 'HCAHeart9845436',
# 'HCAHeartST13146206',
# 'HCAHeartST10773166',
# 'HCAHeart9508627',
# 'HCAHeartST11064574',
# 'HCAHeartST11350193',
# 'HCAHeartST13146202',
# 'HCAHeartST11350184',
# 'HCAHeartST13180618',
# 'HCAHeartST11350195',
# 'HCAHeartST11350197',
# 'HCAHeart9845432',
# 'HCAHeartST13146204',
# 'HCAHeartST10773165',
# 'HCAHeartST13146207',
# 'HCAHeartST11064576',
# 'HCAHeart9845434',
# 'HCAHeart9508628',
# 'HCAHeartST13180615',
# 'HCAHeart9845435',
# 'HCAHeartST11350186',
# 'HCAHeart9845431',
# 'HCAHeartST13180617',
# 'HCAHeartST11350198',
# 'HCAHeartST11350192',
# 'HCAHeartST10773168',
# 'HCAHeart9508629',
# 'HCAHeartST13146203',
# 'HCAHeartST13146208',
# 'HCAHeartST13146205',
# 'HCAHeartST11350187',
# 'HCAHeartST10773167',
# 'HCAHeartST11064575',
# 'HCAHeartST13168796']

# %% [markdown]
# copy the output and assign it to a list in python

# %%
mapped_samples = ['HCAHeartST13146201',
'HCAHeartST10773170',
'HCAHeart9845433',
'HCAHeartST10773171',
'HCAHeartST11064577',
'HCAHeartST10773169',
'HCAHeartST11350194',
'HCAHeartST13180616',
'HCAHeart9845436',
'HCAHeartST13146206',
'HCAHeartST10773166',
'HCAHeart9508627',
'HCAHeartST11064574',
'HCAHeartST11350193',
'HCAHeartST13146202',
'HCAHeartST11350184',
'HCAHeartST13180618',
'HCAHeartST11350195',
'HCAHeartST11350197',
'HCAHeart9845432',
'HCAHeartST13146204',
'HCAHeartST10773165',
'HCAHeartST13146207',
'HCAHeartST11064576',
'HCAHeart9845434',
'HCAHeart9508628',
'HCAHeartST13180615',
'HCAHeart9845435',
'HCAHeartST11350186',
'HCAHeart9845431',
'HCAHeartST13180617',
'HCAHeartST11350198',
'HCAHeartST11350192',
'HCAHeartST10773168',
'HCAHeart9508629',
'HCAHeartST13146203',
'HCAHeartST13146208',
'HCAHeartST13146205',
'HCAHeartST11350187',
'HCAHeartST10773167',
'HCAHeartST11064575',
'HCAHeartST13168796']

# %% [markdown]
# Remove the entries that have already been mapped as per the list above

# %%
download_resume = pd.read_csv('../../raw_data/downloads_table.csv', index_col=0, header=None)
download_resume = download_resume[~download_resume[1].isin(mapped_samples)]
download_resume
# Out:
#                       1                                                  2  \
# 0
# 108  HCAHeartST11350196  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 109  HCAHeartST11350196  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 110  HCAHeartST11350196  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 111  HCAHeartST11350196  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 172  HCAHeartST13180619  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 173  HCAHeartST13180619  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 174  HCAHeartST13180619  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 175  HCAHeartST13180619  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 176  HCAHeartST13189995  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 177  HCAHeartST13189995  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 178  HCAHeartST13189995  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 179  HCAHeartST13189995  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 180  HCAHeartST13189996  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 181  HCAHeartST13189996  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 182  HCAHeartST13189996  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 183  HCAHeartST13189996  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 184  HCAHeartST13189997  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 185  HCAHeartST13189997  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 186  HCAHeartST13189997  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# 187  HCAHeartST13189997  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
#
#                                               3
# 0
# 108  HCAHeartST11350196_S1_L001_I1_001.fastq.gz
# 109  HCAHeartST11350196_S1_L001_I2_001.fastq.gz
# 110  HCAHeartST11350196_S1_L001_R1_001.fastq.gz
# 111  HCAHeartST11350196_S1_L001_R2_001.fastq.gz
# 172  HCAHeartST13180619_S1_L001_I1_001.fastq.gz
# 173  HCAHeartST13180619_S1_L001_I2_001.fastq.gz
# 174  HCAHeartST13180619_S1_L001_R1_001.fastq.gz
# 175  HCAHeartST13180619_S1_L001_R2_001.fastq.gz
# 176  HCAHeartST13189995_S1_L001_I1_001.fastq.gz
# 177  HCAHeartST13189995_S1_L001_I2_001.fastq.gz
# 178  HCAHeartST13189995_S1_L001_R1_001.fastq.gz
# 179  HCAHeartST13189995_S1_L001_R2_001.fastq.gz
# 180  HCAHeartST13189996_S1_L001_I1_001.fastq.gz
# 181  HCAHeartST13189996_S1_L001_I2_001.fastq.gz
# 182  HCAHeartST13189996_S1_L001_R1_001.fastq.gz
# 183  HCAHeartST13189996_S1_L001_R2_001.fastq.gz
# 184  HCAHeartST13189997_S1_L001_I1_001.fastq.gz
# 185  HCAHeartST13189997_S1_L001_I2_001.fastq.gz
# 186  HCAHeartST13189997_S1_L001_R1_001.fastq.gz
# 187  HCAHeartST13189997_S1_L001_R2_001.fastq.gz

# %% [markdown]
# Write it to a new file and dont forget to pass the correct file to the bash script below

# %%
download_resume.to_csv('../../raw_data/downloads_table_resume.csv', header=None)

# %% [markdown]
# ## Mapping
# This script loops over each line from the csv file created above, extracts the sample name, download url and file name from it and creates a folder named after the sample. \
# Then it will download the 4 files associated with the sample and once that is done begin processing it with 'kb count'. \
# Once that is done the downloaded files are deleted and only the mapping output remains in the sample folder

# %%
# %%bash
#
# metadata='../../raw_data/downloads_table_resume.csv'
# output_path='../../mapping/'
# index_output="../../kb_index/"
#
# if [ ! -f "$metadata" ]; then
#     echo "File not found: $metadata"
#     exit 1
# fi
#
# while IFS=, read -r index sample url file_name; do
#     mkdir -p "$output_path/$sample"
#
#     axel -n 10 --output="$output_path/$sample/$file_name" "$url"
#
#     downloaded_files+=("$output_path/$sample/$file_name")
#
#     if [ ${#downloaded_files[@]} -eq 4 ]; then
#         echo "Processing files for sample: $sample"
#
#         kb count -i "$index_output/transcriptome.idx" -g "$index_output/transcripts_to_genes.txt" -x 10XV3 \
#             --h5ad \
#             "$output_path/$sample"/*.fastq.gz \
#             -o "$output_path/$sample/"
#
#         echo "Deleting downloaded files for sample: $sample"
#         rm "${downloaded_files[@]}"
#         downloaded_files=()
#     fi
# done < "$metadata"

# %% [markdown]
# ## Checking quality of mapping

# %% [markdown]
# Returning a dataframe of a given json file

# %%
def json_file2df(filepath):
    with open(filepath, 'r') as f:
        json_dict = json.load(f)
        json_df = pd.DataFrame.from_dict(json_dict, orient='index').T
        return json_df

# %% [markdown]
# Creating a dataframe containing all the values per sample of inspect.json and run_info.json

# %%
samples = meta_data['Source Name'].tolist()
mapping_path = '../../mapping/'
inspect_dfs = []
run_info_dfs = []
for sample in samples:
    sample_path = os.path.join(mapping_path, sample)
    if os.path.isdir(os.path.join(sample_path)):
        inspect_dfs.append(
            json_file2df(os.path.join(sample_path, 'inspect.json'))
            .assign(sample = sample)
            .set_index('sample')
        )
        run_info_dfs.append(
            json_file2df(os.path.join(sample_path, 'run_info.json'))
            .assign(sample = sample)
            .set_index('sample')
        )
run_data_df = pd.concat(
    [
        pd.concat(inspect_dfs),
        pd.concat(run_info_dfs)
    ],
    axis=1
)
run_data_df
# Out:
#                     numRecords     numReads  numBarcodes  \
# sample
# HCAHeart9508627     47130023.0  122490962.0    1195537.0
# HCAHeart9508627     47130023.0  122490962.0    1195537.0
# HCAHeart9508627     47130023.0  122490962.0    1195537.0
# HCAHeart9508627     47130023.0  122490962.0    1195537.0
# HCAHeart9508628     29995588.0   68319577.0    1352388.0
# ...                        ...          ...          ...
# HCAHeartST13189996  30765177.0   95429900.0    1336076.0
# HCAHeartST13189997  24050868.0   96645219.0    1145561.0
# HCAHeartST13189997  24050868.0   96645219.0    1145561.0
# HCAHeartST13189997  24050868.0   96645219.0    1145561.0
# HCAHeartST13189997  24050868.0   96645219.0    1145561.0
#
#                     medianReadsPerBarcode  meanReadsPerBarcode     numUMIs  \
# sample
# HCAHeart9508627                       3.0           102.456856  12870879.0
# HCAHeart9508627                       3.0           102.456856  12870879.0
# HCAHeart9508627                       3.0           102.456856  12870879.0
# HCAHeart9508627                       3.0           102.456856  12870879.0
# HCAHeart9508628                       3.0            50.517734  11429158.0
# ...                                   ...                  ...         ...
# HCAHeartST13189996                    3.0            71.425503  11575608.0
# HCAHeartST13189997                    4.0            84.364970  10120614.0
# HCAHeartST13189997                    4.0            84.364970  10120614.0
# HCAHeartST13189997                    4.0            84.364970  10120614.0
# HCAHeartST13189997                    4.0            84.364970  10120614.0
#
#                     numBarcodeUMIs  medianUMIsPerBarcode  meanUMIsPerBarcode  \
# sample
# HCAHeart9508627         34811681.0                   1.0           29.118029
# HCAHeart9508627         34811681.0                   1.0           29.118029
# HCAHeart9508627         34811681.0                   1.0           29.118029
# HCAHeart9508627         34811681.0                   1.0           29.118029
# HCAHeart9508628         25382277.0                   1.0           18.768487
# ...                            ...                   ...                 ...
# HCAHeartST13189996      26577854.0                   1.0           19.892472
# HCAHeartST13189997      20197220.0                   1.0           17.630855
# HCAHeartST13189997      20197220.0                   1.0           17.630855
# HCAHeartST13189997      20197220.0                   1.0           17.630855
# HCAHeartST13189997      20197220.0                   1.0           17.630855
#
#                      gtRecords  ...  n_bootstraps  n_processed  \
# sample                          ...
# HCAHeart9508627     13649729.0  ...             0    802912772
# HCAHeart9508627     13649729.0  ...             0    802912772
# HCAHeart9508627     13649729.0  ...             0    802912772
# HCAHeart9508627     13649729.0  ...             0    802912772
# HCAHeart9508628      9300094.0  ...             0    631380062
# ...                        ...  ...           ...          ...
# HCAHeartST13189996   7410731.0  ...             0    683092784
# HCAHeartST13189997   4939434.0  ...             0    678404950
# HCAHeartST13189997   4939434.0  ...             0    678404950
# HCAHeartST13189997   4939434.0  ...             0    678404950
# HCAHeartST13189997   4939434.0  ...             0    678404950
#
#                     n_pseudoaligned  n_unique p_pseudoaligned p_unique  \
# sample
# HCAHeart9508627           122490962  26880876            15.3      3.3
# HCAHeart9508627           122490962  26880876            15.3      3.3
# HCAHeart9508627           122490962  26880876            15.3      3.3
# HCAHeart9508627           122490962  26880876            15.3      3.3
# HCAHeart9508628            68319577  20000878            10.8      3.2
# ...                             ...       ...             ...      ...
# HCAHeartST13189996         95429900  32247029            14.0      4.7
# HCAHeartST13189997         96645219  32624312            14.2      4.8
# HCAHeartST13189997         96645219  32624312            14.2      4.8
# HCAHeartST13189997         96645219  32624312            14.2      4.8
# HCAHeartST13189997         96645219  32624312            14.2      4.8
#
#                    kallisto_version index_version                start_time  \
# sample
# HCAHeart9508627              0.50.1            13  Thu Apr 11 15:37:55 2024
# HCAHeart9508627              0.50.1            13  Thu Apr 11 15:37:55 2024
# HCAHeart9508627              0.50.1            13  Thu Apr 11 15:37:55 2024
# HCAHeart9508627              0.50.1            13  Thu Apr 11 15:37:55 2024
# HCAHeart9508628              0.50.1            13  Thu Apr 11 16:01:13 2024
# ...                             ...           ...                       ...
# HCAHeartST13189996           0.50.1            13  Fri Apr 12 18:40:02 2024
# HCAHeartST13189997           0.50.1            13  Fri Apr 12 18:59:53 2024
# HCAHeartST13189997           0.50.1            13  Fri Apr 12 18:59:53 2024
# HCAHeartST13189997           0.50.1            13  Fri Apr 12 18:59:53 2024
# HCAHeartST13189997           0.50.1            13  Fri Apr 12 18:59:53 2024
#
#                                                                  call
# sample
# HCAHeart9508627     /home/ceger/miniforge3/envs/heart_mapping/lib/...
# HCAHeart9508627     /home/ceger/miniforge3/envs/heart_mapping/lib/...
# HCAHeart9508627     /home/ceger/miniforge3/envs/heart_mapping/lib/...
# HCAHeart9508627     /home/ceger/miniforge3/envs/heart_mapping/lib/...
# HCAHeart9508628     /home/ceger/miniforge3/envs/heart_mapping/lib/...
# ...                                                               ...
# HCAHeartST13189996  /home/ceger/miniforge3/envs/heart_mapping/lib/...
# HCAHeartST13189997  /home/ceger/miniforge3/envs/heart_mapping/lib/...
# HCAHeartST13189997  /home/ceger/miniforge3/envs/heart_mapping/lib/...
# HCAHeartST13189997  /home/ceger/miniforge3/envs/heart_mapping/lib/...
# HCAHeartST13189997  /home/ceger/miniforge3/envs/heart_mapping/lib/...
#
# [188 rows x 25 columns]

# %% [markdown]
# Plotting a Histogram of the Values

# %%
for column in run_data_df.select_dtypes(exclude='string').columns:
    run_data_df[column].plot(kind='hist', bins=10, edgecolor='black')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.grid(True)
    plt.legend([column], loc='upper right')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/0-240409-data_loading.ipynb Cell 30 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B132.187.167.21/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/0-240409-data_loading.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for column in run_data_df.select_dtypes(exclude='string').columns:
# ----> <a href='vscode-notebook-cell://ssh-remote%2B132.187.167.21/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/0-240409-data_loading.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     run_data_df[column].plot(kind='hist', bins=10, edgecolor='black')
#       <a href='vscode-notebook-cell://ssh-remote%2B132.187.167.21/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/0-240409-data_loading.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     plt.xlabel('Values')
#       <a href='vscode-notebook-cell://ssh-remote%2B132.187.167.21/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/0-240409-data_loading.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     plt.ylabel('Frequency')
#
# File ~/miniforge3/envs/heart_mapping/lib/python3.10/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/miniforge3/envs/heart_mapping/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/miniforge3/envs/heart_mapping/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
#     449     self._args_adjust()
# --> 450     self._compute_plot_data()
#     451     self._setup_subplots()
#     452     self._make_plot()
#
# File ~/miniforge3/envs/heart_mapping/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:635, in MPLPlot._compute_plot_data(self)
#     633 # no non-numeric frames or series allowed
#     634 if is_empty:
# --> 635     raise TypeError("no numeric data to plot")
#     637 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
