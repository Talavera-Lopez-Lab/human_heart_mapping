# %% [markdown]
# # Notebook for mapping ATACseq Data
#
# Raw data downloaded from [**here**](https://www.ebi.ac.uk/biostudies/arrayexpress/studies/E-MTAB-12919/sdrf)
#
#     Developed by: Christian Eger
#     Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg
#     Created on: 240415
#     Last modified: 240416

# %%
import os
import pandas as pd
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating input file for download and processing script
#
# Downloaded from [**here**](https://www.ebi.ac.uk/biostudies/arrayexpress/studies/E-MTAB-12919)

# %%
data_path = '../.data/'

# %%
meta_data = pd.read_csv(
    filepath_or_buffer=os.path.join(data_path, 'E-MTAB-12919.sdrf.txt'),
    sep='\t',
)
meta_data
# Out:
#             Source Name Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# 0       HCAHeart9508819         ERS15408182        SAMEA113413051
# 1       HCAHeart9508819         ERS15408182        SAMEA113413051
# 2       HCAHeart9508819         ERS15408182        SAMEA113413051
# 3       HCAHeart9508819         ERS15408182        SAMEA113413051
# 4       HCAHeart9508820         ERS15408183        SAMEA113413052
# ..                  ...                 ...                   ...
# 183  HCAHeartST13188801         ERS15408227        SAMEA113413096
# 184  HCAHeartST13188802         ERS15408228        SAMEA113413097
# 185  HCAHeartST13188802         ERS15408228        SAMEA113413097
# 186  HCAHeartST13188802         ERS15408228        SAMEA113413097
# 187  HCAHeartST13188802         ERS15408228        SAMEA113413097
#
#     Characteristics[organism] Characteristics[age]  \
# 0                Homo sapiens             55 to 60
# 1                Homo sapiens             55 to 60
# 2                Homo sapiens             55 to 60
# 3                Homo sapiens             55 to 60
# 4                Homo sapiens             60 to 65
# ..                        ...                  ...
# 183              Homo sapiens             70 to 75
# 184              Homo sapiens             70 to 75
# 185              Homo sapiens             70 to 75
# 186              Homo sapiens             70 to 75
# 187              Homo sapiens             70 to 75
#
#     Characteristics[developmental stage] Characteristics[sex]  \
# 0                                  adult                 male
# 1                                  adult                 male
# 2                                  adult                 male
# 3                                  adult                 male
# 4                                  adult                 male
# ..                                   ...                  ...
# 183                                adult               female
# 184                                adult               female
# 185                                adult               female
# 186                                adult               female
# 187                                adult               female
#
#     Characteristics[individual] Characteristics[organism part]  \
# 0                            D3           heart left ventricle
# 1                            D3           heart left ventricle
# 2                            D3           heart left ventricle
# 3                            D3           heart left ventricle
# 4                            D7           right cardiac atrium
# ..                          ...                            ...
# 183                        AV13          atrioventricular node
# 184                        AV13          atrioventricular node
# 185                        AV13          atrioventricular node
# 186                        AV13          atrioventricular node
# 187                        AV13          atrioventricular node
#
#     Characteristics[disease]  ...          Assay Name   Technology Type  \
# 0                     normal  ...     HCAHeart9508819  sequencing assay
# 1                     normal  ...     HCAHeart9508819  sequencing assay
# 2                     normal  ...     HCAHeart9508819  sequencing assay
# 3                     normal  ...     HCAHeart9508819  sequencing assay
# 4                     normal  ...     HCAHeart9508820  sequencing assay
# ..                       ...  ...                 ...               ...
# 183                   normal  ...  HCAHeartST13188801  sequencing assay
# 184                   normal  ...  HCAHeartST13188802  sequencing assay
# 185                   normal  ...  HCAHeartST13188802  sequencing assay
# 186                   normal  ...  HCAHeartST13188802  sequencing assay
# 187                   normal  ...  HCAHeartST13188802  sequencing assay
#
#     Comment[ENA_EXPERIMENT]                                   Scan Name  \
# 0               ERX10811516     HCAHeart9508819_S1_L001_I1_001.fastq.gz
# 1               ERX10811516     HCAHeart9508819_S1_L001_I2_001.fastq.gz
# 2               ERX10811516     HCAHeart9508819_S1_L001_R1_001.fastq.gz
# 3               ERX10811516     HCAHeart9508819_S1_L001_R2_001.fastq.gz
# 4               ERX10811517     HCAHeart9508820_S1_L001_I1_001.fastq.gz
# ..                      ...                                         ...
# 183             ERX10811561  HCAHeartST13188801_S1_L001_R2_001.fastq.gz
# 184             ERX10811562  HCAHeartST13188802_S1_L001_I1_001.fastq.gz
# 185             ERX10811562  HCAHeartST13188802_S1_L001_I2_001.fastq.gz
# 186             ERX10811562  HCAHeartST13188802_S1_L001_R1_001.fastq.gz
# 187             ERX10811562  HCAHeartST13188802_S1_L001_R2_001.fastq.gz
#
#                    Comment[SUBMITTED_FILE_NAME] Comment[ENA_RUN]  \
# 0       HCAHeart9508819_S1_L001_I1_001.fastq.gz      ERR11403725
# 1       HCAHeart9508819_S1_L001_I2_001.fastq.gz      ERR11403725
# 2       HCAHeart9508819_S1_L001_R1_001.fastq.gz      ERR11403725
# 3       HCAHeart9508819_S1_L001_R2_001.fastq.gz      ERR11403725
# 4       HCAHeart9508820_S1_L001_I1_001.fastq.gz      ERR11403726
# ..                                          ...              ...
# 183  HCAHeartST13188801_S1_L001_R2_001.fastq.gz      ERR11403770
# 184  HCAHeartST13188802_S1_L001_I1_001.fastq.gz      ERR11403771
# 185  HCAHeartST13188802_S1_L001_I2_001.fastq.gz      ERR11403771
# 186  HCAHeartST13188802_S1_L001_R1_001.fastq.gz      ERR11403771
# 187  HCAHeartST13188802_S1_L001_R2_001.fastq.gz      ERR11403771
#
#                                     Comment[FASTQ_URI] Comment[read_index]  \
# 0    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# 1    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index2
# 2    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read1
# 3    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
# 4    ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# ..                                                 ...                 ...
# 183  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
# 184  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index1
# 185  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...              index2
# 186  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read1
# 187  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...               read2
#
#     Comment[read_type] Factor Value[organism part]
# 0       sample_barcode        heart left ventricle
# 1         cell_barcode        heart left ventricle
# 2               paired        heart left ventricle
# 3               paired        heart left ventricle
# 4       sample_barcode        right cardiac atrium
# ..                 ...                         ...
# 183             paired       atrioventricular node
# 184     sample_barcode       atrioventricular node
# 185       cell_barcode       atrioventricular node
# 186             paired       atrioventricular node
# 187             paired       atrioventricular node
#
# [188 rows x 47 columns]
