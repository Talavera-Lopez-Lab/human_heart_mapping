# %%
import pandas as pd

# %%
rna_seq_meta_data = pd.read_table('../.data/meta_data/E-MTAB-12916.sdrf.txt',
                                  index_col='Description')
rna_seq_meta_data.head()
# Out:
#                                      Source Name Comment[ENA_SAMPLE]  \
# Description
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508628_HCAHeart9508820  HCAHeart9508628         ERS15408105
#
#                                 Comment[BioSD_SAMPLE]  \
# Description
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508628_HCAHeart9508820        SAMEA113412974
#
#                                 Characteristics[organism]  \
# Description
# HCAHeart9508627_HCAHeart9508819              Homo sapiens
# HCAHeart9508627_HCAHeart9508819              Homo sapiens
# ...

# %%
atac_seq_meta_data = pd.read_table('../.data/meta_data/E-MTAB-12919.sdrf.txt',
                                   index_col='Description')
atac_seq_meta_data.head()
# Out:
#                                      Source Name Comment[ENA_SAMPLE]  \
# Description
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508819         ERS15408182
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508819         ERS15408182
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508819         ERS15408182
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508819         ERS15408182
# HCAHeart9508628_HCAHeart9508820  HCAHeart9508820         ERS15408183
#
#                                 Comment[BioSD_SAMPLE]  \
# Description
# HCAHeart9508627_HCAHeart9508819        SAMEA113413051
# HCAHeart9508627_HCAHeart9508819        SAMEA113413051
# HCAHeart9508627_HCAHeart9508819        SAMEA113413051
# HCAHeart9508627_HCAHeart9508819        SAMEA113413051
# HCAHeart9508628_HCAHeart9508820        SAMEA113413052
#
#                                 Characteristics[organism]  \
# Description
# HCAHeart9508627_HCAHeart9508819              Homo sapiens
# HCAHeart9508627_HCAHeart9508819              Homo sapiens
# ...

# %%
keys = ['rna', 'atac']
meta_data = pd.concat(
    [rna_seq_meta_data, atac_seq_meta_data],
    axis=1,
    keys= keys
)
meta_data.head()
# Out:
#                                              rna                      \
#                                      Source Name Comment[ENA_SAMPLE]
# Description
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508628_HCAHeart9508820  HCAHeart9508628         ERS15408105
#
#                                                        \
#                                 Comment[BioSD_SAMPLE]
# Description
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508628_HCAHeart9508820        SAMEA113412974
#
#                                                            \
# ...

# %%
columns = [
    'Source Name',
    'Comment[SUBMITTED_FILE_NAME]',
    'Comment[FASTQ_URI]'
]

meta_data_download = pd.concat([meta_data[key][columns].add_suffix(f'_{key}') for key in keys], axis=1)
meta_data_download.head()
# Out:
#                                  Source Name_rna  \
# Description
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627
# HCAHeart9508628_HCAHeart9508820  HCAHeart9508628
#
#                                         Comment[SUBMITTED_FILE_NAME]_rna  \
# Description
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627_S1_L001_I1_001.fastq.gz
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627_S1_L001_I2_001.fastq.gz
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627_S1_L001_R1_001.fastq.gz
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627_S1_L001_R2_001.fastq.gz
# HCAHeart9508628_HCAHeart9508820  HCAHeart9508628_S1_L001_I1_001.fastq.gz
#
#                                                             Comment[FASTQ_URI]_rna  \
# Description
# HCAHeart9508627_HCAHeart9508819  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR114/ERR114...
# ...

# %%
meta_data_download.to_csv('../.data/meta_data/downloads_table.csv', header=None)

# %%
# %%bash
#
# export PATH=/home/ceger/CellRanger/cellranger-arc-2.0.2:$PATH
#
# metadata="/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/.data/meta_data/downloads_table.csv"
# output_path="/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/.data/mapping"
# index_output="/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/.data/cr_arc_index/GRCh38"
#
#
# if [ ! -f "$metadata" ]; then
#     echo "File not found: $metadata"
#     exit 1
# fi
#
# while IFS=, read -r index sample_rna file_name_rna url_rna sample_atac file_name_atac url_atac; do
#     sample_output_path="$output_path/$index"
#     rna_file_path="$sample_output_path/$sample_rna"
#     atac_file_path="$sample_output_path/$sample_atac"
#     rna_file="$rna_file_path/$file_name_rna"
#     atac_file="$atac_file_path/$file_name_atac"
#
#     mkdir -p $rna_file_path
#     mkdir -p $atac_file_path
#
#     echo "fastqs,sample,library_type" > "$sample_output_path/libraries.csv"
#     echo "$rna_file_path","$sample_rna","Gene Expression" >> "$sample_output_path/libraries.csv"
#     echo "$atac_file_path","$sample_atac","Chromatin Accessibility" >> "$sample_output_path/libraries.csv"
#
#
#     axel -n 10 --output="$rna_file" "$url_rna"
#     axel -n 10 --output="$atac_file" "$url_atac"
#
#     if [ "$(find "$rna_file_path" -maxdepth 1 -type f | wc -l)" -eq 4 ] && [ "$(find "$atac_file_path" -maxdepth 1 -type f | wc -l)" -eq 4 ]; then
#         echo "Both folders contain exactly 4 files."
#         cellranger-arc count    --id="$index" \
#                                 --reference="/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/.data/cr_arc_index/GRCh38" \
#                                 --libraries="/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/.data/mapping/HCAHeart9508627_HCAHeart9508819/libraries.csv" \
#                                 --localcores=16 \
#                                 --localmem=32
#         mv "$index" "$sample_output_path"
#         rm -r "$rna_file_path"
#         rm -r "$atac_file_path"
#     fi
# done < "$metadata"
# Out:
# Both folders contain exactly 4 files.
# Martian Runtime - v4.0.5
# Serving UI at http://carlos:37229?auth=vOsbhRJKoSDMbegO15JMgFB5xGMUIxjOPhbU53GFVQQ
#
# Running preflight checks (please wait)...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/.data/cr_arc_index/GRCh38) on carlos...
# Checking optional arguments...
# mrc: v4.0.5
#
# mrp: v4.0.5
#
# Anaconda: Python 3.7.6
#
# numpy: 1.19.2
#
# scipy: 1.2.1
#
# pysam: 0.16.0.1
#
# h5py: 2.8.0
#
# pandas: 0.24.2
#
# STAR: 2.7.2a
#
# samtools: samtools 1.10
# Using htslib 1.10.2
# Copyright (C) 2019 Genome Research Ltd.
#
# 2024-04-19 16:23:07 [runtime] (ready)           ID.HCAHeart9508627_HCAHeart9508819.SC_ATAC_GEX_COUNTER_CS.SC_ATAC_GEX_COUNTER.SPLIT_SAMPLE_DEF
# ...

# %%
# %%bash
# pwd
# Out:
# /mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/1-240419-CellRanger_ARC

# %%
# %%bash
#
# export PATH=/home/ceger/CellRanger/cellranger-arc-2.0.2:$PATH
# pwd
#
# cellranger-arc count --id="../.data/mapping/HCAHeart9508627_HCAHeart9508819/output" \
#                     --reference="/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/.data/cr_arc_index/GRCh38" \
#                         --libraries="/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/.data/mapping/HCAHeart9508627_HCAHeart9508819/libraries.csv" \
#                         --localcores=16 \
#                         --localmem=32
# Out:
# /mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/1-240419-CellRanger_ARC
# error: Invalid value for '--id <ID>': must contain only letters, digits, underscores, and dashes.
#
# For more information try --help
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/1-240419-CellRanger_ARC/1-240419-mapping.ipynb Cell 9 line 1
# ...
