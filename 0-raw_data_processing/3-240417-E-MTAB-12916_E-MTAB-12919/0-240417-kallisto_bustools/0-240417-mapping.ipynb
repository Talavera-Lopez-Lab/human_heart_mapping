# %%
import pandas as pd

# %%
rna_seq_meta_data = pd.read_table('../.data/meta_data/E-MTAB-12916.sdrf.txt',
                                  index_col='Description')
rna_seq_meta_data.head()
# Out:
#                                      Source Name Comment[ENA_SAMPLE]  \
# Description
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508628_HCAHeart9508820  HCAHeart9508628         ERS15408105
#
#                                 Comment[BioSD_SAMPLE]  \
# Description
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508628_HCAHeart9508820        SAMEA113412974
#
#                                 Characteristics[organism]  \
# Description
# HCAHeart9508627_HCAHeart9508819              Homo sapiens
# HCAHeart9508627_HCAHeart9508819              Homo sapiens
# ...

# %%
atac_seq_meta_data = pd.read_table('../.data/meta_data/E-MTAB-12919.sdrf.txt',
                                   index_col='Description')
atac_seq_meta_data.head()
# Out:
#                                      Source Name Comment[ENA_SAMPLE]  \
# Description
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508819         ERS15408182
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508819         ERS15408182
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508819         ERS15408182
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508819         ERS15408182
# HCAHeart9508628_HCAHeart9508820  HCAHeart9508820         ERS15408183
#
#                                 Comment[BioSD_SAMPLE]  \
# Description
# HCAHeart9508627_HCAHeart9508819        SAMEA113413051
# HCAHeart9508627_HCAHeart9508819        SAMEA113413051
# HCAHeart9508627_HCAHeart9508819        SAMEA113413051
# HCAHeart9508627_HCAHeart9508819        SAMEA113413051
# HCAHeart9508628_HCAHeart9508820        SAMEA113413052
#
#                                 Characteristics[organism]  \
# Description
# HCAHeart9508627_HCAHeart9508819              Homo sapiens
# HCAHeart9508627_HCAHeart9508819              Homo sapiens
# ...

# %%
meta_data = pd.concat(
    [rna_seq_meta_data, atac_seq_meta_data],
    axis=1,
    keys=['rna', 'atac']
)
meta_data.head()
# Out:
#                                              rna                      \
#                                      Source Name Comment[ENA_SAMPLE]
# Description
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508627_HCAHeart9508819  HCAHeart9508627         ERS15408104
# HCAHeart9508628_HCAHeart9508820  HCAHeart9508628         ERS15408105
#
#                                                        \
#                                 Comment[BioSD_SAMPLE]
# Description
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508627_HCAHeart9508819        SAMEA113412973
# HCAHeart9508628_HCAHeart9508820        SAMEA113412974
#
#                                                            \
# ...

# %%
columns = {
    'Source Name',
    'Comment[ENA_SAMPLE]'
}

# %%
pd.concat([meta_data[key][columns] for key in meta_data.keys()], axis=1)
# Out:
# /tmp/ipykernel_1017485/207712218.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   pd.concat([meta_data[key][columns] for key in meta_data.keys()], axis=0)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/0-240417-kallisto_bustools/0-240417-mapping.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B132.187.167.21/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/3-240417-E-MTAB-12916_E-MTAB-12919/0-240417-kallisto_bustools/0-240417-mapping.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> pd.concat([meta_data[key][columns] for key in meta_data.keys()], axis=0)
#
# ...

# %%
meta_data.keys()
# Out:
# MultiIndex([( 'rna',                          'Source Name'),
#             ( 'rna',                  'Comment[ENA_SAMPLE]'),
#             ( 'rna',                'Comment[BioSD_SAMPLE]'),
#             ( 'rna',            'Characteristics[organism]'),
#             ( 'rna',                 'Characteristics[age]'),
#             ( 'rna', 'Characteristics[developmental stage]'),
#             ( 'rna',                 'Characteristics[sex]'),
#             ( 'rna',          'Characteristics[individual]'),
#             ( 'rna',       'Characteristics[organism part]'),
#             ( 'rna',             'Characteristics[disease]'),
#             ( 'rna',            'Characteristics[genotype]'),
#             ( 'rna',                        'Material Type'),
#             ( 'rna',                         'Protocol REF'),
#             ( 'rna',                       'Protocol REF.1'),
#             ( 'rna',                       'Protocol REF.2'),
# ...

# %%
meta_data.to_csv('../.data/downloads_table.csv')
