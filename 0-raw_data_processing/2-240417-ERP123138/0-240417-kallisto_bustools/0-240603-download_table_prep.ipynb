# %% [markdown]
# # Adjusting metadata table to make it suitable for downloading and mapping dataset ERP123138
#
# Raw data downloaded from [here](https://www.ebi.ac.uk/ena/browser/view/PRJEB39602)
#
#     Developed by: Christian Eger
#     Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg
#     Created on: 240603
#     Last modified: 240605

# %% [markdown]
# ## Import modules

# %%
import pandas as pd

# %% [markdown]
# ## Inspect default table

# %%
df = pd.read_csv('.data/meta_data/filereport_read_run_PRJEB39602_tsv.txt', sep='\t', index_col=0)
df
# Out:
#                 sample_accession experiment_accession run_accession  tax_id  \
# study_accession
# PRJEB39602          SAMEA7249749           ERX4319127    ERR6449746    9606
# PRJEB39602          SAMEA7249695           ERX4319157    ERR6449748    9606
# PRJEB39602          SAMEA7249707           ERX4319184    ERR6449751    9606
# PRJEB39602          SAMEA7249690           ERX4319178    ERR6449752    9606
# PRJEB39602          SAMEA7249729           ERX4319192    ERR6449757    9606
# ...                          ...                  ...           ...     ...
# PRJEB39602          SAMEA7249837           ERX4319213    ERR7423470    9606
# PRJEB39602          SAMEA7762099           ERX4733969    ERR7423473    9606
# PRJEB39602          SAMEA7249680           ERX4319154    ERR7423476    9606
# PRJEB39602          SAMEA7249680           ERX4319154    ERR7423477    9606
# PRJEB39602          SAMEA7762101           ERX4733977    ERR7423479    9606
#
#                 scientific_name  fastq_ftp  \
# study_accession
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# ...                         ...        ...
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
#
#                                                      submitted_ftp  sra_ftp  \
# study_accession
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449751/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449752/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449757/H...      NaN
# ...                                                            ...      ...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423470/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423473/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423476/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...      NaN
#
#                  bam_ftp
# study_accession
# PRJEB39602           NaN
# PRJEB39602           NaN
# PRJEB39602           NaN
# PRJEB39602           NaN
# PRJEB39602           NaN
# ...                  ...
# PRJEB39602           NaN
# PRJEB39602           NaN
# PRJEB39602           NaN
# PRJEB39602           NaN
# PRJEB39602           NaN
#
# [512 rows x 9 columns]

# %% [markdown]
# ## Make Adjustments

# %% [markdown]
# Splitting up download link into individual links to download I1, R1 and R2 files

# %%
df[['I1_url', 'R1_url', 'R2_url']] = df['submitted_ftp'].str.split(';', expand=True)
df
# Out:
#                 sample_accession experiment_accession run_accession  tax_id  \
# study_accession
# PRJEB39602          SAMEA7249749           ERX4319127    ERR6449746    9606
# PRJEB39602          SAMEA7249695           ERX4319157    ERR6449748    9606
# PRJEB39602          SAMEA7249707           ERX4319184    ERR6449751    9606
# PRJEB39602          SAMEA7249690           ERX4319178    ERR6449752    9606
# PRJEB39602          SAMEA7249729           ERX4319192    ERR6449757    9606
# ...                          ...                  ...           ...     ...
# PRJEB39602          SAMEA7249837           ERX4319213    ERR7423470    9606
# PRJEB39602          SAMEA7762099           ERX4733969    ERR7423473    9606
# PRJEB39602          SAMEA7249680           ERX4319154    ERR7423476    9606
# PRJEB39602          SAMEA7249680           ERX4319154    ERR7423477    9606
# PRJEB39602          SAMEA7762101           ERX4733977    ERR7423479    9606
#
#                 scientific_name  fastq_ftp  \
# study_accession
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# ...                         ...        ...
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
# PRJEB39602         Homo sapiens        NaN
#
#                                                      submitted_ftp  sra_ftp  \
# study_accession
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449751/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449752/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449757/H...      NaN
# ...                                                            ...      ...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423470/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423473/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423476/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...      NaN
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...      NaN
#
#                  bam_ftp                                             I1_url  \
# study_accession
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449751/H...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449752/H...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449757/H...
# ...                  ...                                                ...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423470/H...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423473/H...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423476/H...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...
# PRJEB39602           NaN  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...
#
#                                                             R1_url  \
# study_accession
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449751/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449752/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449757/H...
# ...                                                            ...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423470/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423473/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423476/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...
#
#                                                             R2_url
# study_accession
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449751/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449752/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449757/H...
# ...                                                            ...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423470/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423473/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423476/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...
# PRJEB39602       ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...
#
# [512 rows x 12 columns]

# %% [markdown]
# Expand Table Rows such that each filetype (I1, R1 and R2) has its own row, sharing the sample name with eachother, but not sharing url_type, url and filename columns \
# Create new columns url_type (describing the file type downloaded in this rows url) and filename (name of the file to be downloaded)

# %%
# Initialize an empty list to hold new rows
new_rows = []

# Iterate over the original DataFrame rows
for _, row in df.iterrows():
    # Create a new row for I1_url
    new_row_I1 = row.drop(labels=['R1_url', 'R2_url']).to_dict()
    new_row_I1['url_type'] = 'I1_url'
    new_row_I1['url'] = row['I1_url']
    new_rows.append(new_row_I1)

    # Create a new row for R1_url
    new_row_R1 = row.drop(labels=['I1_url', 'R2_url']).to_dict()
    new_row_R1['url_type'] = 'R1_url'
    new_row_R1['url'] = row['R1_url']
    new_rows.append(new_row_R1)

    # Create a new row for R2_url
    new_row_R2 = row.drop(labels=['I1_url', 'R1_url']).to_dict()
    new_row_R2['url_type'] = 'R2_url'
    new_row_R2['url'] = row['R2_url']
    new_rows.append(new_row_R2)

# Create a new DataFrame from the list of new rows
new_df = pd.DataFrame(new_rows)
new_df = new_df.drop(columns=['I1_url', 'R1_url', 'R2_url'])
new_df['filename'] = new_df['url'].str.split('/').str[-1]
new_df
# Out:
#      sample_accession experiment_accession run_accession  tax_id  \
# 0        SAMEA7249749           ERX4319127    ERR6449746    9606
# 1        SAMEA7249749           ERX4319127    ERR6449746    9606
# 2        SAMEA7249749           ERX4319127    ERR6449746    9606
# 3        SAMEA7249695           ERX4319157    ERR6449748    9606
# 4        SAMEA7249695           ERX4319157    ERR6449748    9606
# ...               ...                  ...           ...     ...
# 1531     SAMEA7249680           ERX4319154    ERR7423477    9606
# 1532     SAMEA7249680           ERX4319154    ERR7423477    9606
# 1533     SAMEA7762101           ERX4733977    ERR7423479    9606
# 1534     SAMEA7762101           ERX4733977    ERR7423479    9606
# 1535     SAMEA7762101           ERX4733977    ERR7423479    9606
#
#      scientific_name  fastq_ftp  \
# 0       Homo sapiens        NaN
# 1       Homo sapiens        NaN
# 2       Homo sapiens        NaN
# 3       Homo sapiens        NaN
# 4       Homo sapiens        NaN
# ...              ...        ...
# 1531    Homo sapiens        NaN
# 1532    Homo sapiens        NaN
# 1533    Homo sapiens        NaN
# 1534    Homo sapiens        NaN
# 1535    Homo sapiens        NaN
#
#                                           submitted_ftp  sra_ftp  bam_ftp  \
# 0     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...      NaN      NaN
# 1     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...      NaN      NaN
# 2     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...      NaN      NaN
# 3     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...      NaN      NaN
# 4     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...      NaN      NaN
# ...                                                 ...      ...      ...
# 1531  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...      NaN      NaN
# 1532  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...      NaN      NaN
# 1533  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...      NaN      NaN
# 1534  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...      NaN      NaN
# 1535  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...      NaN      NaN
#
#      url_type                                                url  \
# 0      I1_url  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...
# 1      R1_url  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...
# 2      R2_url  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...
# 3      I1_url  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...
# 4      R1_url  ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...
# ...       ...                                                ...
# 1531   R1_url  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...
# 1532   R2_url  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...
# 1533   I1_url  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...
# 1534   R1_url  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...
# 1535   R2_url  ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...
#
#                                      filename
# 0     HCAHeart7664653_S1_L001_I1_001.fastq.gz
# 1     HCAHeart7664653_S1_L001_R1_001.fastq.gz
# 2     HCAHeart7664653_S1_L001_R2_001.fastq.gz
# 3     HCAHeart7664652_S1_L001_I1_001.fastq.gz
# 4     HCAHeart7664652_S1_L001_R1_001.fastq.gz
# ...                                       ...
# 1531         H0035_RV_S2_L004_R1_001.fastq.gz
# 1532         H0035_RV_S2_L004_R2_001.fastq.gz
# 1533  HCAHeart7702882_S1_L001_I1_001.fastq.gz
# 1534  HCAHeart7702882_S1_L001_R1_001.fastq.gz
# 1535  HCAHeart7702882_S1_L001_R2_001.fastq.gz
#
# [1536 rows x 12 columns]

# %% [markdown]
# Remove rows containing I1 files

# %%
new_df = new_df[new_df['url_type'] != 'I1_url']

# %%
new_df.to_csv('.data/meta_data/downloads_table.csv')

# %% [markdown]
# ## Inspect table in object

# %%
import experiment
import os


GEX_Experiment = experiment.TenX_GEX_Experiment(
    parent_dir=os.getcwd(),
    meta_data_path='meta_data/downloads_table.csv',
    sample_col='run_accession',
    file_name_col='filename',
    url_col='url',
    mapping_output='mapping_py'
)

GEX_Experiment.meta_data
# Out:
#                Unnamed: 0 sample_accession experiment_accession  tax_id  \
# run_accession
# ERR6449746              1     SAMEA7249749           ERX4319127    9606
# ERR6449746              2     SAMEA7249749           ERX4319127    9606
# ERR6449748              4     SAMEA7249695           ERX4319157    9606
# ERR6449748              5     SAMEA7249695           ERX4319157    9606
# ERR6449751              7     SAMEA7249707           ERX4319184    9606
# ...                   ...              ...                  ...     ...
# ERR7423476           1529     SAMEA7249680           ERX4319154    9606
# ERR7423477           1531     SAMEA7249680           ERX4319154    9606
# ERR7423477           1532     SAMEA7249680           ERX4319154    9606
# ERR7423479           1534     SAMEA7762101           ERX4733977    9606
# ERR7423479           1535     SAMEA7762101           ERX4733977    9606
#
#               scientific_name  fastq_ftp  \
# run_accession
# ERR6449746       Homo sapiens        NaN
# ERR6449746       Homo sapiens        NaN
# ERR6449748       Homo sapiens        NaN
# ERR6449748       Homo sapiens        NaN
# ERR6449751       Homo sapiens        NaN
# ...                       ...        ...
# ERR7423476       Homo sapiens        NaN
# ERR7423477       Homo sapiens        NaN
# ERR7423477       Homo sapiens        NaN
# ERR7423479       Homo sapiens        NaN
# ERR7423479       Homo sapiens        NaN
#
#                                                    submitted_ftp  sra_ftp  \
# run_accession
# ERR6449746     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...      NaN
# ERR6449746     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...      NaN
# ERR6449748     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...      NaN
# ERR6449748     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...      NaN
# ERR6449751     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449751/H...      NaN
# ...                                                          ...      ...
# ERR7423476     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423476/H...      NaN
# ERR7423477     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...      NaN
# ERR7423477     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...      NaN
# ERR7423479     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...      NaN
# ERR7423479     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...      NaN
#
#                bam_ftp url_type  \
# run_accession
# ERR6449746         NaN   R1_url
# ERR6449746         NaN   R2_url
# ERR6449748         NaN   R1_url
# ERR6449748         NaN   R2_url
# ERR6449751         NaN   R1_url
# ...                ...      ...
# ERR7423476         NaN   R2_url
# ERR7423477         NaN   R1_url
# ERR7423477         NaN   R2_url
# ERR7423479         NaN   R1_url
# ERR7423479         NaN   R2_url
#
#                                                              url  \
# run_accession
# ERR6449746     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...
# ERR6449746     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449746/H...
# ERR6449748     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...
# ERR6449748     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449748/H...
# ERR6449751     ftp.sra.ebi.ac.uk/vol1/run/ERR644/ERR6449751/H...
# ...                                                          ...
# ERR7423476     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423476/H...
# ERR7423477     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...
# ERR7423477     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423477/H...
# ERR7423479     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...
# ERR7423479     ftp.sra.ebi.ac.uk/vol1/run/ERR742/ERR7423479/H...
#
#                                               filename
# run_accession
# ERR6449746     HCAHeart7664653_S1_L001_R1_001.fastq.gz
# ERR6449746     HCAHeart7664653_S1_L001_R2_001.fastq.gz
# ERR6449748     HCAHeart7664652_S1_L001_R1_001.fastq.gz
# ERR6449748     HCAHeart7664652_S1_L001_R2_001.fastq.gz
# ERR6449751     HCAHeart7698016_S1_L001_R1_001.fastq.gz
# ...                                                ...
# ERR7423476            H0035_RV_S2_L003_R2_001.fastq.gz
# ERR7423477            H0035_RV_S2_L004_R1_001.fastq.gz
# ERR7423477            H0035_RV_S2_L004_R2_001.fastq.gz
# ERR7423479     HCAHeart7702882_S1_L001_R1_001.fastq.gz
# ERR7423479     HCAHeart7702882_S1_L001_R2_001.fastq.gz
#
# [1024 rows x 12 columns]

# %%
len(GEX_Experiment.meta_data.index.unique())
# Out:
# 512
