# %%
import experiment
import subprocess
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/2-240417-ERP123138/test_notebook.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B132.187.167.21/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/2-240417-ERP123138/test_notebook.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import experiment
#       <a href='vscode-notebook-cell://ssh-remote%2B132.187.167.21/mnt/LaCIE/ceger/Projects/human_heart_mapping/human_heart_mapping/0-raw_data_processing/2-240417-ERP123138/test_notebook.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import subprocess
# ...

# %%
df = pd.read_csv('filereport_read_run_PRJEB39602_tsv(1).txt', sep='\t')
df
# Out:
#     study_accession sample_accession experiment_accession run_accession  \
# 0        PRJEB39602     SAMEA7249749           ERX4319127    ERR6449746
# 1        PRJEB39602     SAMEA7249695           ERX4319157    ERR6449748
# 2        PRJEB39602     SAMEA7249707           ERX4319184    ERR6449751
# 3        PRJEB39602     SAMEA7249690           ERX4319178    ERR6449752
# 4        PRJEB39602     SAMEA7249729           ERX4319192    ERR6449757
# ..              ...              ...                  ...           ...
# 507      PRJEB39602     SAMEA7249837           ERX4319213    ERR7423470
# 508      PRJEB39602     SAMEA7762099           ERX4733969    ERR7423473
# 509      PRJEB39602     SAMEA7249680           ERX4319154    ERR7423476
# 510      PRJEB39602     SAMEA7249680           ERX4319154    ERR7423477
# 511      PRJEB39602     SAMEA7762101           ERX4733977    ERR7423479
#
#      tax_id scientific_name  fastq_ftp  \
# 0      9606    Homo sapiens        NaN
# ...
